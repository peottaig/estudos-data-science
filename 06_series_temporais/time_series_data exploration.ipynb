# %%
#Imports
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
from datetime import datetime

from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters
# Out:
# <function pandas.plotting._misc.register() -> 'None'>

# %%
base = pd.read_csv("AirPassengers.csv")
base.head()
# base.shape
# Out:
#      Month  #Passengers
# 0  1949-01          112
# 1  1949-02          118
# 2  1949-03          132
# 3  1949-04          129
# 4  1949-05          121

# %%
print(base.dtypes)
# Out:
# Month          object
# #Passengers     int64
# dtype: object

# %%
base.index
# Out:
# RangeIndex(start=0, stop=144, step=1)

# %%
dateparse = lambda dates: datetime.strptime(dates, '%Y-%m')
base = pd.read_csv('AirPassengers.csv', parse_dates= ['Month'],
                   index_col= 'Month', date_parser = dateparse)
base
# Out:
# C:\Users\luigg\AppData\Local\Temp\ipykernel_13360\3679790245.py:2: FutureWarning: The argument 'date_parser' is deprecated and will be removed in a future version. Please use 'date_format' instead, or read your data in as 'object' dtype and then call 'to_datetime'.
#   base = pd.read_csv('AirPassengers.csv', parse_dates= ['Month'],
#             #Passengers
# Month
# 1949-01-01          112
# 1949-02-01          118
# 1949-03-01          132
# 1949-04-01          129
# 1949-05-01          121
# ...                 ...
# 1960-08-01          606
# 1960-09-01          508
# 1960-10-01          461
# 1960-11-01          390
# 1960-12-01          432
#
# [144 rows x 1 columns]

# %%
base.index
# Out:
# DatetimeIndex(['1949-01-01', '1949-02-01', '1949-03-01', '1949-04-01',
#                '1949-05-01', '1949-06-01', '1949-07-01', '1949-08-01',
#                '1949-09-01', '1949-10-01',
#                ...
#                '1960-03-01', '1960-04-01', '1960-05-01', '1960-06-01',
#                '1960-07-01', '1960-08-01', '1960-09-01', '1960-10-01',
#                '1960-11-01', '1960-12-01'],
#               dtype='datetime64[ns]', name='Month', length=144, freq=None)

# %%
ts = base['#Passengers']
ts
# Out:
# Month
# 1949-01-01    112
# 1949-02-01    118
# 1949-03-01    132
# 1949-04-01    129
# 1949-05-01    121
#              ...
# 1960-08-01    606
# 1960-09-01    508
# 1960-10-01    461
# 1960-11-01    390
# 1960-12-01    432
# Name: #Passengers, Length: 144, dtype: int64

# %%
ts[0]
# Out:
# C:\Users\luigg\AppData\Local\Temp\ipykernel_13360\342760361.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   ts[0]
# np.int64(112)

# %%
ts[datetime(1949,2,1)]
# Out:
# np.int64(118)

# %%
ts['1949-01']
# Out:
# Month
# 1949-01-01    112
# Name: #Passengers, dtype: int64

# %%
# ts['1950-01-01':'1950-07-31']
ts[:'1950-07-31']
# Out:
# Month
# 1949-01-01    112
# 1949-02-01    118
# 1949-03-01    132
# 1949-04-01    129
# 1949-05-01    121
# 1949-06-01    135
# 1949-07-01    148
# 1949-08-01    148
# 1949-09-01    136
# 1949-10-01    119
# 1949-11-01    104
# 1949-12-01    118
# 1950-01-01    115
# 1950-02-01    126
# 1950-03-01    141
# 1950-04-01    135
# 1950-05-01    125
# 1950-06-01    149
# 1950-07-01    170
# Name: #Passengers, dtype: int64

# %%
test = ts.iloc[1:7]
test
# Out:
# Month
# 1949-02-01    118
# 1949-03-01    132
# 1949-04-01    129
# 1949-05-01    121
# 1949-06-01    135
# 1949-07-01    148
# Name: #Passengers, dtype: int64

# %%
plt.plot(ts)

# %%
ts_ano = ts.resample('a').sum()
plt.plot(ts_ano)
# To see the trend
# Out:
# C:\Users\luigg\AppData\Local\Temp\ipykernel_13360\3975350010.py:1: FutureWarning: 'a' is deprecated and will be removed in a future version, please use 'YE' instead.
#   ts_ano = ts.resample('a').sum()

# %%
# Monthly view
ts_month = ts.groupby([lambda x: x.month]).sum()
plt.plot(ts_month)

# %%
ts_dates = ts['1960-01-01':'1960-12-01']
plt.plot(ts_dates)

# %% [markdown]
# ## Revisão ativa
#
# Estado: a revisar. As células acima preservam o estudo anterior; saídas antigas não comprovam uma execução limpa. Consulte o [registro de dificuldades](../00_guia/progresso.md).
#
# - Pergunta ou conceito deste exercício: _preencher_.
# - Por que escolhi esse procedimento: _preencher_.
# - Como conferi a saída: _preencher_.
# - Conclusão e limitação: _preencher_.
#
# ## Prática independente
#
# Refaça uma parte com a solução fechada e altere os dados ou a pergunta. Registre o que mudou e onde precisou consultar documentação. Ao terminar, reinicie o kernel, execute tudo e atualize o progresso.
