# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
from datetime import datetime
from statsmodels.tsa.seasonal import seasonal_decompose

from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters
# Out:
# <function pandas.plotting._misc.register() -> 'None'>

# %%
data = pd.read_csv('AirPassengers.csv')
dateparse = lambda dates: datetime.strptime(dates, '%Y-%m')
data = pd.read_csv('AirPassengers.csv', parse_dates=['Month'],
                   index_col='Month', date_parser = dateparse)

ts = data['#Passengers']
ts
# Out:
# C:\Users\luigg\AppData\Local\Temp\ipykernel_22616\47732582.py:3: FutureWarning: The argument 'date_parser' is deprecated and will be removed in a future version. Please use 'date_format' instead, or read your data in as 'object' dtype and then call 'to_datetime'.
#   data = pd.read_csv('AirPassengers.csv', parse_dates=['Month'],
# Month
# 1949-01-01    112
# 1949-02-01    118
# 1949-03-01    132
# 1949-04-01    129
# 1949-05-01    121
#              ...
# 1960-08-01    606
# 1960-09-01    508
# 1960-10-01    461
# 1960-11-01    390
# 1960-12-01    432
# Name: #Passengers, Length: 144, dtype: int64

# %%
plt.plot(ts)

# %%
decomposition = seasonal_decompose(ts)

# %%
trend = decomposition.trend
trend
# Out:
# Month
# 1949-01-01   NaN
# 1949-02-01   NaN
# 1949-03-01   NaN
# 1949-04-01   NaN
# 1949-05-01   NaN
#               ..
# 1960-08-01   NaN
# 1960-09-01   NaN
# 1960-10-01   NaN
# 1960-11-01   NaN
# 1960-12-01   NaN
# Name: trend, Length: 144, dtype: float64

# %%
seasonal = decomposition.seasonal
seasonal
# Out:
# Month
# 1949-01-01   -24.748737
# 1949-02-01   -36.188131
# 1949-03-01    -2.241162
# 1949-04-01    -8.036616
# 1949-05-01    -4.506313
#                 ...
# 1960-08-01    62.823232
# 1960-09-01    16.520202
# 1960-10-01   -20.642677
# 1960-11-01   -53.593434
# 1960-12-01   -28.619949
# Name: seasonal, Length: 144, dtype: float64

# %%
resid = decomposition.resid
resid
# Out:
# Month
# 1949-01-01   NaN
# 1949-02-01   NaN
# 1949-03-01   NaN
# 1949-04-01   NaN
# 1949-05-01   NaN
#               ..
# 1960-08-01   NaN
# 1960-09-01   NaN
# 1960-10-01   NaN
# 1960-11-01   NaN
# 1960-12-01   NaN
# Name: resid, Length: 144, dtype: float64

# %%
plt.plot(seasonal)

# %%
plt.plot(trend)

# %%
plt.plot(resid)

# %% [markdown]
# ## Revisão ativa
#
# Estado: a revisar. As células acima preservam o estudo anterior; saídas antigas não comprovam uma execução limpa. Consulte o [registro de dificuldades](../00_guia/progresso.md).
#
# - Pergunta ou conceito deste exercício: _preencher_.
# - Por que escolhi esse procedimento: _preencher_.
# - Como conferi a saída: _preencher_.
# - Conclusão e limitação: _preencher_.
#
# ## Prática independente
#
# Refaça uma parte com a solução fechada e altere os dados ou a pergunta. Registre o que mudou e onde precisou consultar documentação. Ao terminar, reinicie o kernel, execute tudo e atualize o progresso.
